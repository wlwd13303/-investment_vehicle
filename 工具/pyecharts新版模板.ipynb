# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

# %% [markdown]
# # 条形图

# %%
c=(
   Bar({'width':'820px','height':'420px'})
   .add_xaxis(Faker.choose())
   .add_yaxis('商家A',Faker.values())
   .add_yaxis('商家B',Faker.values())
   .set_global_opts(opts.TitleOpts(title='主标题',subtitle='副标题'))
   .set_series_opts(label_opts=opts.LabelOpts(is_show=False),
                  markline_opts=opts.MarkLineOpts(
                  data=[opts.MarkLineItem(y=50,name='yAxis=50')]))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7f2d9cbf0bf347e682a263bb138c3c04" style="width:820px; height:420px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7f2d9cbf0bf347e682a263bb138c3c04 = echarts.init(
#                     document.getElementById('7f2d9cbf0bf347e682a263bb138c3c04'), 'white', {renderer: 'canvas'});
#                 var option_7f2d9cbf0bf347e682a263bb138c3c04 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 131,
#                 147,
#                 149,
#                 64,
#                 28,
#                 87,
#                 97
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "yAxis=50",
#                         "yAxis": 50
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 51,
#                 90,
#                 79,
#                 98,
#                 116,
#                 102,
#                 115
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "yAxis=50",
#                         "yAxis": 50
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_7f2d9cbf0bf347e682a263bb138c3c04.setOption(option_7f2d9cbf0bf347e682a263bb138c3c04);
#         });
#     </script>

# %%
from pyecharts.charts import Bar

bar = Bar()
X=["美国折耳猫", "虎斑猫", "绅士猫", "波斯猫", "加菲猫", "老鼠"]
Y1=[5, 20, 36, 10, 75, 90]
Y2=[10, 25, 36, 10, 60, 20]
bar.add_xaxis(X)
bar.add_yaxis("宠物店A", Y1)
bar.add_yaxis("宠物店B", Y2)
#标题设置
bar.set_global_opts(title_opts=opts.TitleOpts(
    title="老哥示范",
    title_link="http://pyecharts.org/",
    subtitle="老哥太强了",
    pos_left="20%" #pos_left  pos_right   pos_top   pos_bottom
))
#图例配置
bar.set_global_opts(legend_opts=opts.LegendOpts(
    type_="scroll",
    is_show=True,
    orient="vertical",
    legend_icon="circle"))
#视觉配置
bar.set_global_opts(visualmap_opts=opts.VisualMapOpts(
    is_show=True,
    type_="color",
    range_text=("高","低"),
    range_opacity=80,
    orient="horizontal",
    pos_right="20%",
    pos_top="bottom",
    split_number=10))
#bar.render()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="612adebd43a84ce68aece44354e70023" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_612adebd43a84ce68aece44354e70023 = echarts.init(
#                     document.getElementById('612adebd43a84ce68aece44354e70023'), 'white', {renderer: 'canvas'});
#                 var option_612adebd43a84ce68aece44354e70023 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5ba0\u7269\u5e97A",
#             "legendHoverLink": true,
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5ba0\u7269\u5e97B",
#             "legendHoverLink": true,
#             "data": [
#                 10,
#                 25,
#                 36,
#                 10,
#                 60,
#                 20
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5ba0\u7269\u5e97A",
#                 "\u5ba0\u7269\u5e97B"
#             ],
#             "selected": {
#                 "\u5ba0\u7269\u5e97A": true,
#                 "\u5ba0\u7269\u5e97B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7f8e\u56fd\u6298\u8033\u732b",
#                 "\u864e\u6591\u732b",
#                 "\u7ec5\u58eb\u732b",
#                 "\u6ce2\u65af\u732b",
#                 "\u52a0\u83f2\u732b",
#                 "\u8001\u9f20"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "text": [
#             "\u9ad8",
#             "\u4f4e"
#         ],
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ],
#             "opacity": 80
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 10,
#         "orient": "horizontal",
#         "top": "bottom",
#         "right": "20%",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_612adebd43a84ce68aece44354e70023.setOption(option_612adebd43a84ce68aece44354e70023);
#         });
#     </script>

# %% [markdown]
# set_global_opts()函数可设置配置项如下：
#
# title_opts标题
#
# legend_opts图例
#
# tooltip_opts提示框
#
# toolbox_opts工具箱
#
# brush_opts区域选择组件
#
# xaxis_optsX轴
#
# yaxis_optsY轴
#
# visualmap_opts视觉映射
#
# datazoom_opts区域缩放
#
# graphic_opts原生图形元素组件
#
# axispointer_opts坐标轴指示器
#
# 视觉映射配置项
#
# bar.set_global_opts(visualmap_opts=opts.VisualMapOpts( is_show=True, type_="color", range_text=("高","低"), range_opacity=80, orient="horizontal", pos_right="20%", pos_top="bottom", split_number=10))

# %% [markdown]
# # 水平条形动图

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.faker import Faker

c = (
        Bar()
        .add_xaxis(Faker.days_attrs)
        .add_yaxis("商家A", Faker.days_values,itemstyle_opts=opts.ItemStyleOpts(color="#d14a61"))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-水平）"),
            datazoom_opts=[opts.DataZoomOpts()],
        )
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="26cd511a37bf41358bb3ff42bc8af265" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_26cd511a37bf41358bb3ff42bc8af265 = echarts.init(
#                     document.getElementById('26cd511a37bf41358bb3ff42bc8af265'), 'white', {renderer: 'canvas'});
#                 var option_26cd511a37bf41358bb3ff42bc8af265 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 12,
#                 29,
#                 5,
#                 11,
#                 6,
#                 4,
#                 22,
#                 12,
#                 23,
#                 26,
#                 21,
#                 2,
#                 3,
#                 24,
#                 30,
#                 2,
#                 3,
#                 20,
#                 26,
#                 13,
#                 27,
#                 14,
#                 18,
#                 2,
#                 3,
#                 20,
#                 25,
#                 18,
#                 27,
#                 12
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color": "#d14a61"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider-\u6c34\u5e73\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false,
#             "filterMode": "filter"
#         }
#     ]
# };
#                 chart_26cd511a37bf41358bb3ff42bc8af265.setOption(option_26cd511a37bf41358bb3ff42bc8af265);
#         });
#     </script>

# %% [markdown]
# # 折线图

# %%
from pyecharts.charts import Line
from pyecharts import options as opts

# 示例数据
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data1 = [123, 153, 89, 107, 98, 23]
data2 = [56, 77, 93, 68, 45, 67]

line = (Line()
       .add_xaxis(cate)
       .add_yaxis('电商渠道', data1, 
                  markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_="average")]))
       .add_yaxis('门店', data2, 
                  is_smooth=True, 
                  markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(name="自定义标记点", 
                                                                             coord=[cate[2], data2[2]], value=data2[2])]))
       .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例", subtitle="我是副标题"))
      )

line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f722ab42478540bca3f48b1f5d23b6dd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f722ab42478540bca3f48b1f5d23b6dd = echarts.init(
#                     document.getElementById('f722ab42478540bca3f48b1f5d23b6dd'), 'white', {renderer: 'canvas'});
#                 var option_f722ab42478540bca3f48b1f5d23b6dd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u7535\u5546\u6e20\u9053",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "Apple",
#                     123
#                 ],
#                 [
#                     "Huawei",
#                     153
#                 ],
#                 [
#                     "Xiaomi",
#                     89
#                 ],
#                 [
#                     "Oppo",
#                     107
#                 ],
#                 [
#                     "Vivo",
#                     98
#                 ],
#                 [
#                     "Meizu",
#                     23
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "type": "average"
#                     }
#                 ]
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u95e8\u5e97",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "Apple",
#                     56
#                 ],
#                 [
#                     "Huawei",
#                     77
#                 ],
#                 [
#                     "Xiaomi",
#                     93
#                 ],
#                 [
#                     "Oppo",
#                     68
#                 ],
#                 [
#                     "Vivo",
#                     45
#                 ],
#                 [
#                     "Meizu",
#                     67
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u81ea\u5b9a\u4e49\u6807\u8bb0\u70b9",
#                         "coord": [
#                             "Xiaomi",
#                             93
#                         ],
#                         "value": 93
#                     }
#                 ]
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u5546\u6e20\u9053",
#                 "\u95e8\u5e97"
#             ],
#             "selected": {
#                 "\u7535\u5546\u6e20\u9053": true,
#                 "\u95e8\u5e97": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_f722ab42478540bca3f48b1f5d23b6dd.setOption(option_f722ab42478540bca3f48b1f5d23b6dd);
#         });
#     </script>

# %% [markdown]
# # 面积图

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
from pyecharts.faker import Faker

c = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values(), areastyle_opts=opts.AreaStyleOpts(opacity=0.5))
    .add_yaxis("商家B", Faker.values(), areastyle_opts=opts.AreaStyleOpts(opacity=0.5))
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-面积图"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="96384883492d459cae9ed079676907dc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_96384883492d459cae9ed079676907dc = echarts.init(
#                     document.getElementById('96384883492d459cae9ed079676907dc'), 'white', {renderer: 'canvas'});
#                 var option_96384883492d459cae9ed079676907dc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     89
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     38
#                 ],
#                 [
#                     "\u8001\u864e",
#                     122
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     66
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     141
#                 ],
#                 [
#                     "\u718a\u732b",
#                     83
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     145
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     107
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     38
#                 ],
#                 [
#                     "\u8001\u864e",
#                     95
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     137
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     44
#                 ],
#                 [
#                     "\u718a\u732b",
#                     125
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     58
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u9762\u79ef\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_96384883492d459cae9ed079676907dc.setOption(option_96384883492d459cae9ed079676907dc);
#         });
#     </script>

# %% [markdown]
# # 饼图

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from random import randint

def pie_base() -> Pie:
    c = (
        Pie()
        .add("", [list(z) for z in zip(['宝马', '法拉利', '奔驰', '奥迪', '大众', '丰田', '特斯拉'],
                                       [randint(1, 20) for _ in range(7)])])
        .set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例"))
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    )
    return c

pie_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2a5a42f158a14e92801f0d027e71a628" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2a5a42f158a14e92801f0d027e71a628 = echarts.init(
#                     document.getElementById('2a5a42f158a14e92801f0d027e71a628'), 'white', {renderer: 'canvas'});
#                 var option_2a5a42f158a14e92801f0d027e71a628 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b9d\u9a6c",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6cd5\u62c9\u5229",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u5954\u9a70",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5965\u8fea",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5927\u4f17",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u4e30\u7530",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u7279\u65af\u62c9",
#                     "value": 16
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5b9d\u9a6c",
#                 "\u6cd5\u62c9\u5229",
#                 "\u5954\u9a70",
#                 "\u5965\u8fea",
#                 "\u5927\u4f17",
#                 "\u4e30\u7530",
#                 "\u7279\u65af\u62c9"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_2a5a42f158a14e92801f0d027e71a628.setOption(option_2a5a42f158a14e92801f0d027e71a628);
#         });
#     </script>

# %%
from pyecharts.charts import Pie
from pyecharts import options as opts

# 示例数据
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data = [153, 124, 107, 99, 89, 46]

pie = (Pie()
       .add('', [list(z) for z in zip(cate, data)],
            radius=["30%", "75%"],
            rosetype="radius"
            )
       .set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例", subtitle="我是副标题"))
       .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {d}%"))
      )

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f6314fbe25c545b5b27ea4cd260de54b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f6314fbe25c545b5b27ea4cd260de54b = echarts.init(
#                     document.getElementById('f6314fbe25c545b5b27ea4cd260de54b'), 'white', {renderer: 'canvas'});
#                 var option_f6314fbe25c545b5b27ea4cd260de54b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "Apple",
#                     "value": 153
#                 },
#                 {
#                     "name": "Huawei",
#                     "value": 124
#                 },
#                 {
#                     "name": "Xiaomi",
#                     "value": 107
#                 },
#                 {
#                     "name": "Oppo",
#                     "value": 99
#                 },
#                 {
#                     "name": "Vivo",
#                     "value": 89
#                 },
#                 {
#                     "name": "Meizu",
#                     "value": 46
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_f6314fbe25c545b5b27ea4cd260de54b.setOption(option_f6314fbe25c545b5b27ea4cd260de54b);
#         });
#     </script>

# %% [markdown]
# # 玫瑰图

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

v = Faker.choose()
c = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(v, Faker.values())],
        radius=["30%", "75%"],
        center=["25%", "50%"],
        rosetype="radius",
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add(
        "",
        [list(z) for z in zip(v, Faker.values())],
        radius=["30%", "75%"],
        center=["75%", "50%"],
        rosetype="area",
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9cc174e73389437b88e0fb3bc4642f87" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9cc174e73389437b88e0fb3bc4642f87 = echarts.init(
#                     document.getElementById('9cc174e73389437b88e0fb3bc4642f87'), 'white', {renderer: 'canvas'});
#                 var option_9cc174e73389437b88e0fb3bc4642f87 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 81
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 130
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 89
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 140
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 72
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 143
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 116
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 25
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-\u73ab\u7470\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_9cc174e73389437b88e0fb3bc4642f87.setOption(option_9cc174e73389437b88e0fb3bc4642f87);
#         });
#     </script>

# %% [markdown]
# # 漏斗图

# %%
import pyecharts.options as opts
from pyecharts.charts import Funnel

x_data = ["展现", "点击", "访问", "咨询", "订单"]
y_data = [100, 80, 60, 40, 20]

data = [[x_data[i], y_data[i]] for i in range(len(x_data))]

(
    Funnel()
    .add(
        series_name="",
        sort_='ascending',
        data_pair=data,
        gap=2,
        tooltip_opts=opts.TooltipOpts(trigger="item", formatter="{a} <br/>{b} : {c}%"),
        label_opts=opts.LabelOpts(is_show=True, position="inside"),
        itemstyle_opts=opts.ItemStyleOpts(border_color="#fff", border_width=1),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="漏斗图", subtitle="纯属虚构"))
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5dc54b6fd96946d3a22c790f883ab309" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5dc54b6fd96946d3a22c790f883ab309 = echarts.init(
#                     document.getElementById('5dc54b6fd96946d3a22c790f883ab309'), 'white', {renderer: 'canvas'});
#                 var option_5dc54b6fd96946d3a22c790f883ab309 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "data": [
#                 {
#                     "name": "\u5c55\u73b0",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u70b9\u51fb",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u8bbf\u95ee",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u54a8\u8be2",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u8ba2\u5355",
#                     "value": 20
#                 }
#             ],
#             "sort": "ascending",
#             "gap": 2,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": "{a} <br/>{b} : {c}%",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "itemStyle": {
#                 "borderColor": "#fff",
#                 "borderWidth": 1
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u54a8\u8be2",
#                 "\u70b9\u51fb",
#                 "\u8ba2\u5355",
#                 "\u8bbf\u95ee",
#                 "\u5c55\u73b0"
#             ],
#             "selected": {
#                 "\u5c55\u73b0": true,
#                 "\u70b9\u51fb": true,
#                 "\u8bbf\u95ee": true,
#                 "\u54a8\u8be2": true,
#                 "\u8ba2\u5355": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u6f0f\u6597\u56fe",
#             "subtext": "\u7eaf\u5c5e\u865a\u6784",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_5dc54b6fd96946d3a22c790f883ab309.setOption(option_5dc54b6fd96946d3a22c790f883ab309);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel, Page
from random import randint

def funnel_base() -> Funnel:
    c = (
        Funnel()
        .add("豪车", [list(z) for z in zip(['宝马', '法拉利', '奔驰', '奥迪', '大众', '丰田', '特斯拉'],
                                         [randint(1, 20) for _ in range(7)])])
        .set_global_opts(title_opts=opts.TitleOpts(title="豪车漏斗图"))
    )
    return c
    
funnel_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9001106cf35a4d1ba9ef60d698ba73db" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9001106cf35a4d1ba9ef60d698ba73db = echarts.init(
#                     document.getElementById('9001106cf35a4d1ba9ef60d698ba73db'), 'white', {renderer: 'canvas'});
#                 var option_9001106cf35a4d1ba9ef60d698ba73db = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u8c6a\u8f66",
#             "data": [
#                 {
#                     "name": "\u5b9d\u9a6c",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u6cd5\u62c9\u5229",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u5954\u9a70",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u5965\u8fea",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5927\u4f17",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u4e30\u7530",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u7279\u65af\u62c9",
#                     "value": 9
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e30\u7530",
#                 "\u5965\u8fea",
#                 "\u5b9d\u9a6c",
#                 "\u7279\u65af\u62c9",
#                 "\u5954\u9a70",
#                 "\u5927\u4f17",
#                 "\u6cd5\u62c9\u5229"
#             ],
#             "selected": {
#                 "\u5b9d\u9a6c": true,
#                 "\u6cd5\u62c9\u5229": true,
#                 "\u5954\u9a70": true,
#                 "\u5965\u8fea": true,
#                 "\u5927\u4f17": true,
#                 "\u4e30\u7530": true,
#                 "\u7279\u65af\u62c9": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u8c6a\u8f66\u6f0f\u6597\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_9001106cf35a4d1ba9ef60d698ba73db.setOption(option_9001106cf35a4d1ba9ef60d698ba73db);
#         });
#     </script>

# %% [markdown]
# # 热力图

# %%
from pyecharts.charts import HeatMap
from pyecharts import options as opts
from pyecharts.faker import Faker
import random

# 示例数据
data = [[i, j, random.randint(0, 100)] for i in range(24) for j in range(7)]

heat = (HeatMap()
        .add_xaxis(Faker.clock)
        .add_yaxis("访客数", 
                   Faker.week, 
                   data,
                   label_opts=opts.LabelOpts(is_show=True, position="inside"))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="HeatMap-基本示例", subtitle="我是副标题"),
            visualmap_opts=opts.VisualMapOpts(),
            legend_opts=opts.LegendOpts(is_show=False))
       )

heat.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a5c2418bb0674cff82e425cabb76776b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a5c2418bb0674cff82e425cabb76776b = echarts.init(
#                     document.getElementById('a5c2418bb0674cff82e425cabb76776b'), 'white', {renderer: 'canvas'});
#                 var option_a5c2418bb0674cff82e425cabb76776b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u8bbf\u5ba2\u6570",
#             "data": [
#                 [
#                     0,
#                     0,
#                     59
#                 ],
#                 [
#                     0,
#                     1,
#                     37
#                 ],
#                 [
#                     0,
#                     2,
#                     44
#                 ],
#                 [
#                     0,
#                     3,
#                     53
#                 ],
#                 [
#                     0,
#                     4,
#                     0
#                 ],
#                 [
#                     0,
#                     5,
#                     36
#                 ],
#                 [
#                     0,
#                     6,
#                     61
#                 ],
#                 [
#                     1,
#                     0,
#                     51
#                 ],
#                 [
#                     1,
#                     1,
#                     19
#                 ],
#                 [
#                     1,
#                     2,
#                     36
#                 ],
#                 [
#                     1,
#                     3,
#                     68
#                 ],
#                 [
#                     1,
#                     4,
#                     15
#                 ],
#                 [
#                     1,
#                     5,
#                     35
#                 ],
#                 [
#                     1,
#                     6,
#                     84
#                 ],
#                 [
#                     2,
#                     0,
#                     36
#                 ],
#                 [
#                     2,
#                     1,
#                     35
#                 ],
#                 [
#                     2,
#                     2,
#                     77
#                 ],
#                 [
#                     2,
#                     3,
#                     29
#                 ],
#                 [
#                     2,
#                     4,
#                     3
#                 ],
#                 [
#                     2,
#                     5,
#                     19
#                 ],
#                 [
#                     2,
#                     6,
#                     44
#                 ],
#                 [
#                     3,
#                     0,
#                     95
#                 ],
#                 [
#                     3,
#                     1,
#                     25
#                 ],
#                 [
#                     3,
#                     2,
#                     17
#                 ],
#                 [
#                     3,
#                     3,
#                     37
#                 ],
#                 [
#                     3,
#                     4,
#                     99
#                 ],
#                 [
#                     3,
#                     5,
#                     82
#                 ],
#                 [
#                     3,
#                     6,
#                     41
#                 ],
#                 [
#                     4,
#                     0,
#                     47
#                 ],
#                 [
#                     4,
#                     1,
#                     66
#                 ],
#                 [
#                     4,
#                     2,
#                     44
#                 ],
#                 [
#                     4,
#                     3,
#                     24
#                 ],
#                 [
#                     4,
#                     4,
#                     6
#                 ],
#                 [
#                     4,
#                     5,
#                     17
#                 ],
#                 [
#                     4,
#                     6,
#                     42
#                 ],
#                 [
#                     5,
#                     0,
#                     19
#                 ],
#                 [
#                     5,
#                     1,
#                     6
#                 ],
#                 [
#                     5,
#                     2,
#                     2
#                 ],
#                 [
#                     5,
#                     3,
#                     37
#                 ],
#                 [
#                     5,
#                     4,
#                     1
#                 ],
#                 [
#                     5,
#                     5,
#                     85
#                 ],
#                 [
#                     5,
#                     6,
#                     30
#                 ],
#                 [
#                     6,
#                     0,
#                     34
#                 ],
#                 [
#                     6,
#                     1,
#                     22
#                 ],
#                 [
#                     6,
#                     2,
#                     41
#                 ],
#                 [
#                     6,
#                     3,
#                     53
#                 ],
#                 [
#                     6,
#                     4,
#                     26
#                 ],
#                 [
#                     6,
#                     5,
#                     50
#                 ],
#                 [
#                     6,
#                     6,
#                     84
#                 ],
#                 [
#                     7,
#                     0,
#                     66
#                 ],
#                 [
#                     7,
#                     1,
#                     55
#                 ],
#                 [
#                     7,
#                     2,
#                     99
#                 ],
#                 [
#                     7,
#                     3,
#                     73
#                 ],
#                 [
#                     7,
#                     4,
#                     74
#                 ],
#                 [
#                     7,
#                     5,
#                     14
#                 ],
#                 [
#                     7,
#                     6,
#                     100
#                 ],
#                 [
#                     8,
#                     0,
#                     18
#                 ],
#                 [
#                     8,
#                     1,
#                     7
#                 ],
#                 [
#                     8,
#                     2,
#                     43
#                 ],
#                 [
#                     8,
#                     3,
#                     21
#                 ],
#                 [
#                     8,
#                     4,
#                     11
#                 ],
#                 [
#                     8,
#                     5,
#                     65
#                 ],
#                 [

# %% [markdown]
# # 日历图

# %%
import datetime
import random

from pyecharts import options as opts
from pyecharts.charts import Calendar


def calendar_interval_1() -> Calendar:
    begin = datetime.date(2019, 1, 1)
    end = datetime.date(2019, 12, 27)
    data = [
        [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
        for i in range(0, (end - begin).days + 1, 2)  # 隔天统计
    ]

    calendar = (
        Calendar(init_opts=opts.InitOpts(width="1200px")).add(
            "", data, calendar_opts=opts.CalendarOpts(range_="2019"))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Calendar-2019年步数统计"),
            visualmap_opts=opts.VisualMapOpts(
                max_=25000,
                min_=1000,
                orient="horizontal",
                is_piecewise=True,
                pos_top="230px",
                pos_left="100px",
            ),
        )
    )
    return calendar

calendar_interval_1().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="765de310c61e475f830432211d169809" style="width:1200px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_765de310c61e475f830432211d169809 = echarts.init(
#                     document.getElementById('765de310c61e475f830432211d169809'), 'white', {renderer: 'canvas'});
#                 var option_765de310c61e475f830432211d169809 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2019-01-01",
#                     7002
#                 ],
#                 [
#                     "2019-01-03",
#                     13055
#                 ],
#                 [
#                     "2019-01-05",
#                     12323
#                 ],
#                 [
#                     "2019-01-07",
#                     14972
#                 ],
#                 [
#                     "2019-01-09",
#                     21132
#                 ],
#                 [
#                     "2019-01-11",
#                     3300
#                 ],
#                 [
#                     "2019-01-13",
#                     1532
#                 ],
#                 [
#                     "2019-01-15",
#                     14357
#                 ],
#                 [
#                     "2019-01-17",
#                     19218
#                 ],
#                 [
#                     "2019-01-19",
#                     8854
#                 ],
#                 [
#                     "2019-01-21",
#                     11099
#                 ],
#                 [
#                     "2019-01-23",
#                     21789
#                 ],
#                 [
#                     "2019-01-25",
#                     10608
#                 ],
#                 [
#                     "2019-01-27",
#                     10975
#                 ],
#                 [
#                     "2019-01-29",
#                     1910
#                 ],
#                 [
#                     "2019-01-31",
#                     7898
#                 ],
#                 [
#                     "2019-02-02",
#                     3351
#                 ],
#                 [
#                     "2019-02-04",
#                     24986
#                 ],
#                 [
#                     "2019-02-06",
#                     10084
#                 ],
#                 [
#                     "2019-02-08",
#                     5923
#                 ],
#                 [
#                     "2019-02-10",
#                     4997
#                 ],
#                 [
#                     "2019-02-12",
#                     17438
#                 ],
#                 [
#                     "2019-02-14",
#                     3178
#                 ],
#                 [
#                     "2019-02-16",
#                     1415
#                 ],
#                 [
#                     "2019-02-18",
#                     9370
#                 ],
#                 [
#                     "2019-02-20",
#                     1507
#                 ],
#                 [
#                     "2019-02-22",
#                     1711
#                 ],
#                 [
#                     "2019-02-24",
#                     13870
#                 ],
#                 [
#                     "2019-02-26",
#                     1660
#                 ],
#                 [
#                     "2019-02-28",
#                     22143
#                 ],
#                 [
#                     "2019-03-02",
#                     18816
#                 ],
#                 [
#                     "2019-03-04",
#                     16855
#                 ],
#                 [
#                     "2019-03-06",
#                     10011
#                 ],
#                 [
#                     "2019-03-08",
#                     9624
#                 ],
#                 [
#                     "2019-03-10",
#                     20954
#                 ],
#                 [
#                     "2019-03-12",
#                     14369
#                 ],
#                 [
#                     "2019-03-14",
#                     23335
#                 ],
#                 [
#                     "2019-03-16",
#                     20254
#                 ],
#                 [
#                     "2019-03-18",
#                     14487
#                 ],
#                 [
#                     "2019-03-20",
#                     12034
#                 ],
#                 [
#                     "2019-03-22",
#                     5512
#                 ],
#                 [
#                     "2019-03-24",
#                     19605
#                 ],
#                 [
#                     "2019-03-26",
#                     3877
#                 ],
#                 [
#                     "2019-03-28",
#                     20880
#                 ],
#                 [
#                     "2019-03-30",
#                     10610
#                 ],
#                 [
#                     "2019-04-01",
#                     16376
#                 ],
#                 [
#                     "2019-04-03",
#                     20173
#                 ],
#                 [
#                     "2019-04-05",
#                     3651
#                 ],
#                 [
#                     "2019-04-07",
#                     10923
#                 ],
#                 [
#                     "2019-04-09",
#                     14922
#                 ],
#                 [
#                     "2019-04-11",
#                     8589
#                 ],
#                 [
#                     "2019-04-13",
#                     13015
#                 ],
#                 [
#                     "2019-04-15",
#                     19358
#                 ],
#                 [
#                     "2019-04-17",
#                     13264
#                 ],
#                 [
#                     "2019-04-19",
#                     9186
#                 ],
#                 [
#                     "2019-04-21",
#                     10192
#                 ],
#                 [
#                     "2019-04-23",
#                     5074
#                 ],
#                 [
#                     "2019-04-25",
#                     21691
#                 ],
#                 [
#                     "2019-04-27",
#                     13779
#                 ],
#                 [
#                     "2019-04-29",
#                     24405
#                 ],
#                 [
#                     "2019-05-01",
#                     19186
#                 ],
#                 [
#                     "2019-05-03",
#                     17121
#                 ],
#                 [
#                     "2019-05-05",
#                     5538
#                 ],
#                 [
#                     "2019-05-07",
#                     1018
#                 ],
#                 [
#                     "2019-05-09",
#                     3170
#                 ],
#                 [
#                     "2019-05-11",
#                     24111
#                 ],
#                 [
#                     "2019-05-13",
#                     17305
#                 ],
#                 [
#                     "2019-05-15",
#                     1709
#                 ],
#                 [

# %% [markdown]
# # 水球图

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid, Page
from pyecharts.globals import SymbolType


def liquid() -> Liquid:
    c = (
        Liquid()
        .add("lq", [0.67, 0.30, 0.15])
        .set_global_opts(title_opts=opts.TitleOpts(title="Liquid"))
    )
    return c
liquid().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="49e590f146d14b54ba483b67a6daa55b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_49e590f146d14b54ba483b67a6daa55b = echarts.init(
#                     document.getElementById('49e590f146d14b54ba483b67a6daa55b'), 'white', {renderer: 'canvas'});
#                 var option_49e590f146d14b54ba483b67a6daa55b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.67,
#                 0.3,
#                 0.15
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": true,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Liquid",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_49e590f146d14b54ba483b67a6daa55b.setOption(option_49e590f146d14b54ba483b67a6daa55b);
#         });
#     </script>

# %% [markdown]
# # 散点图

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter
from pyecharts.faker import Faker

c = (
    Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Scatter-VisualMap(Size)"),
        visualmap_opts=opts.VisualMapOpts(type_="size", max_=150, min_=20),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e53ee99365ff4d3781852c2ccd80552a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e53ee99365ff4d3781852c2ccd80552a = echarts.init(
#                     document.getElementById('e53ee99365ff4d3781852c2ccd80552a'), 'white', {renderer: 'canvas'});
#                 var option_e53ee99365ff4d3781852c2ccd80552a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     103
#                 ],
#                 [
#                     "\u8292\u679c",
#                     54
#                 ],
#                 [
#                     "\u8461\u8404",
#                     137
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     64
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     143
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     69
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     65
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6B",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     122
#                 ],
#                 [
#                     "\u8292\u679c",
#                     57
#                 ],
#                 [
#                     "\u8461\u8404",
#                     67
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     83
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     105
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     34
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     149
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-VisualMap(Size)",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 20,
#         "max": 150,
#         "inRange": {
#             "symbolSize": [
#                 20,
#                 50
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_e53ee99365ff4d3781852c2ccd80552a.setOption(option_e53ee99365ff4d3781852c2ccd80552a);
#         });
#     </script>

# %% [markdown]
# # 三维散点图

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter3D
import random


data = [[random.randint(0, 150), random.randint(0, 100), random.randint(0, 100)]
        for _ in range(1000)]

scatter3D = (Scatter3D()
             .add("", data)
             .set_global_opts(
                 title_opts=opts.TitleOpts("Scatter3D-基本示例"),
                 visualmap_opts=opts.VisualMapOpts(range_color=Faker.visual_color))
            )

scatter3D.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="74f611a695cd4abdae4ea320a00187e0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_74f611a695cd4abdae4ea320a00187e0 = echarts.init(
#                     document.getElementById('74f611a695cd4abdae4ea320a00187e0'), 'white', {renderer: 'canvas'});
#                 var option_74f611a695cd4abdae4ea320a00187e0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter3D",
#             "data": [
#                 [
#                     99,
#                     83,
#                     24
#                 ],
#                 [
#                     13,
#                     61,
#                     62
#                 ],
#                 [
#                     73,
#                     68,
#                     64
#                 ],
#                 [
#                     64,
#                     68,
#                     83
#                 ],
#                 [
#                     147,
#                     58,
#                     86
#                 ],
#                 [
#                     40,
#                     52,
#                     78
#                 ],
#                 [
#                     41,
#                     62,
#                     9
#                 ],
#                 [
#                     95,
#                     77,
#                     35
#                 ],
#                 [
#                     145,
#                     59,
#                     63
#                 ],
#                 [
#                     120,
#                     55,
#                     64
#                 ],
#                 [
#                     25,
#                     15,
#                     66
#                 ],
#                 [
#                     96,
#                     12,
#                     50
#                 ],
#                 [
#                     79,
#                     30,
#                     49
#                 ],
#                 [
#                     80,
#                     40,
#                     6
#                 ],
#                 [
#                     62,
#                     57,
#                     49
#                 ],
#                 [
#                     29,
#                     79,
#                     75
#                 ],
#                 [
#                     121,
#                     87,
#                     53
#                 ],
#                 [
#                     52,
#                     17,
#                     4
#                 ],
#                 [
#                     79,
#                     99,
#                     7
#                 ],
#                 [
#                     92,
#                     99,
#                     83
#                 ],
#                 [
#                     137,
#                     54,
#                     8
#                 ],
#                 [
#                     86,
#                     42,
#                     24
#                 ],
#                 [
#                     124,
#                     32,
#                     79
#                 ],
#                 [
#                     66,
#                     13,
#                     80
#                 ],
#                 [
#                     131,
#                     32,
#                     90
#                 ],
#                 [
#                     33,
#                     37,
#                     44
#                 ],
#                 [
#                     10,
#                     59,
#                     3
#                 ],
#                 [
#                     13,
#                     25,
#                     76
#                 ],
#                 [
#                     0,
#                     74,
#                     82
#                 ],
#                 [
#                     120,
#                     76,
#                     1
#                 ],
#                 [
#                     83,
#                     43,
#                     54
#                 ],
#                 [
#                     122,
#                     85,
#                     18
#                 ],
#                 [
#                     40,
#                     54,
#                     83
#                 ],
#                 [
#                     26,
#                     88,
#                     46
#                 ],
#                 [
#                     114,
#                     67,
#                     2
#                 ],
#                 [
#                     80,
#                     46,
#                     2
#                 ],
#                 [
#                     126,
#                     64,
#                     97
#                 ],
#                 [
#                     24,
#                     10,
#                     48
#                 ],
#                 [
#                     73,
#                     20,
#                     100
#                 ],
#                 [
#                     12,
#                     86,
#                     67
#                 ],
#                 [
#                     53,
#                     49,
#                     41
#                 ],
#                 [
#                     69,
#                     19,
#                     62
#                 ],
#                 [
#                     125,
#                     32,
#                     88
#                 ],
#                 [
#                     32,
#                     20,
#                     7
#                 ],
#                 [
#                     67,
#                     87,
#                     9
#                 ],
#                 [
#                     90,
#                     53,
#                     59
#                 ],
#                 [
#                     78,
#                     41,
#                     79
#                 ],
#                 [
#                     64,
#                     57,
#                     6
#                 ],
#                 [
#                     17,
#                     73,
#                     96
#                 ],
#                 [
#                     61,
#                     71,
#                     13
#                 ],
#                 [
#                     70,
#                     9,
#                     41
#                 ],
#                 [
#                     143,
#                     42,
#                     64
#                 ],
#                 [
#                     71,
#                     71,
#                     63
#                 ],
#                 [
#                     116,
#                     74,
#                     96
#                 ],
#                 [
#                     143,
#                     92,
#                     20
#                 ],
#                 [
#                     49,
#                     53,
#                     18
#                 ],
#                 [
#                     15,
#                     37,
#                     94
#                 ],
#                 [
#                     109,
#                     11,
#                     48
#                 ],
#                 [
#                     128,
#                     38,
#                     90
#                 ],
#                 [
#                     22,
#                     58,
#                     24
#                 ],
#                 [
#                     140,
#                     16,

# %% [markdown]
# # 箱线图

# %%
from pyecharts import options as opts
from pyecharts.charts import Boxplot

v1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880, 1000, 980],
    [960, 940, 960, 940, 880, 800, 850, 880, 900, 840, 830, 790],
]
v2 = [
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760, 910, 920],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850, 870, 870],
]
c = Boxplot()
c.add_xaxis(["expr1", "expr2"])
c.add_yaxis("A", c.prepare_data(v1))
c.add_yaxis("B", c.prepare_data(v2))
c.set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="033a23ec567a44e9bc61f9ccf16d6ab0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_033a23ec567a44e9bc61f9ccf16d6ab0 = echarts.init(
#                     document.getElementById('033a23ec567a44e9bc61f9ccf16d6ab0'), 'white', {renderer: 'canvas'});
#                 var option_033a23ec567a44e9bc61f9ccf16d6ab0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "data": [
#                 [
#                     740,
#                     857.5,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     790,
#                     832.5,
#                     880.0,
#                     940.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "data": [
#                 [
#                     740,
#                     760.0,
#                     805.0,
#                     872.5,
#                     920
#                 ],
#                 [
#                     760,
#                     795.0,
#                     815.0,
#                     865.0,
#                     890
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "expr1",
#                 "expr2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "BoxPlot-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_033a23ec567a44e9bc61f9ccf16d6ab0.setOption(option_033a23ec567a44e9bc61f9ccf16d6ab0);
#         });
#     </script>

# %% [markdown]
# # 地图

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
import random

province = ['广东', '湖北', '湖南', '四川', '重庆', '黑龙江', '浙江', '山西', '河北', '安徽', '河南', '山东', '西藏']
data = [(i, random.randint(50, 150)) for i in province]

_map = (
        Map()
        .add("销售额", data, "china")
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Map-基本示例"),
            legend_opts=opts.LegendOpts(is_show=False),
            visualmap_opts=opts.VisualMapOpts(max_=200, is_piecewise=True),
        )
    )

_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="01ce6a55f1e8410ea57db5ecf4621033" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_01ce6a55f1e8410ea57db5ecf4621033 = echarts.init(
#                     document.getElementById('01ce6a55f1e8410ea57db5ecf4621033'), 'white', {renderer: 'canvas'});
#                 var option_01ce6a55f1e8410ea57db5ecf4621033 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u9500\u552e\u989d",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 120
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 117
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 69
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 142
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 95
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 64
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e\u989d"
#             ],
#             "selected": {
#                 "\u9500\u552e\u989d": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Map-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_01ce6a55f1e8410ea57db5ecf4621033.setOption(option_01ce6a55f1e8410ea57db5ecf4621033);
#         });
#     </script>

# %% [markdown]
# # 区域热力图

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType
import random

province = ['杭州', '宁波', '温州', '嘉兴', '丽水', '衢州', '绍兴', '台州', '湖州','金华','舟山']
data = [(i, random.randint(50, 150)) for i in province]

geo = (Geo()
        .add_schema(maptype="浙江")
        .add("门店数", data,
            type_=ChartType.HEATMAP)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(),
            legend_opts=opts.LegendOpts(is_show=False),
            title_opts=opts.TitleOpts(title="Geo-浙江热力地图"))
      )

geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '浙江':'https://assets.pyecharts.org/assets/maps/zhejiang'
#         }
#     });
# </script>
#
#         <div id="0312d4d93cbe48aea3a5b7de145708ca" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '浙江'], function(echarts) {
#                 var chart_0312d4d93cbe48aea3a5b7de145708ca = echarts.init(
#                     document.getElementById('0312d4d93cbe48aea3a5b7de145708ca'), 'white', {renderer: 'canvas'});
#                 var option_0312d4d93cbe48aea3a5b7de145708ca = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u95e8\u5e97\u6570",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         124
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u6ce2",
#                     "value": [
#                         121.56,
#                         29.86,
#                         95
#                     ]
#                 },
#                 {
#                     "name": "\u6e29\u5dde",
#                     "value": [
#                         120.65,
#                         28.01,
#                         52
#                     ]
#                 },
#                 {
#                     "name": "\u5609\u5174",
#                     "value": [
#                         120.76,
#                         30.77,
#                         78
#                     ]
#                 },
#                 {
#                     "name": "\u4e3d\u6c34",
#                     "value": [
#                         119.92,
#                         28.45,
#                         113
#                     ]
#                 },
#                 {
#                     "name": "\u8862\u5dde",
#                     "value": [
#                         118.88,
#                         28.97,
#                         65
#                     ]
#                 },
#                 {
#                     "name": "\u7ecd\u5174",
#                     "value": [
#                         120.58,
#                         30.01,
#                         64
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u5dde",
#                     "value": [
#                         121.420757,
#                         28.656386,
#                         129
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5dde",
#                     "value": [
#                         120.1,
#                         30.86,
#                         86
#                     ]
#                 },
#                 {
#                     "name": "\u91d1\u534e",
#                     "value": [
#                         119.64,
#                         29.12,
#                         79
#                     ]
#                 },
#                 {
#                     "name": "\u821f\u5c71",
#                     "value": [
#                         122.207216,
#                         29.985295,
#                         107
#                     ]
#                 }
#             ],
#             "pointSize": 20,
#             "blurSize": 20,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u95e8\u5e97\u6570"
#             ],
#             "selected": {
#                 "\u95e8\u5e97\u6570": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Geo-\u6d59\u6c5f\u70ed\u529b\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "\u6d59\u6c5f",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_0312d4d93cbe48aea3a5b7de145708ca.setOption(option_0312d4d93cbe48aea3a5b7de145708ca);
#         });
#     </script>

# %% [markdown]
# # 世界地图

# %%
from pyecharts.charts import Map  # 注意这里与老版本pyecharts调用的区别
from pyecharts import options as opts
import random
country = ['China', 'Canada', 'France', 'Japan', 'Russia', 'USA']
data_world = [(i, random.randint(100, 200)) for i in country]
world = (
    Map()
    .add('', # 此处没取名，所以空着
      data_world, # 数据
      'world') # 地图类型
    .set_global_opts(
        title_opts=opts.TitleOpts(title='World Map'),
        visualmap_opts=opts.VisualMapOpts(
            max_=200,
            min_=100,
            is_piecewise=True)  # 定义图例为分段型，默认为连续的图例
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
)
world.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="3fdb4b09292a415bb99a8a72d0dc3c14" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_3fdb4b09292a415bb99a8a72d0dc3c14 = echarts.init(
#                     document.getElementById('3fdb4b09292a415bb99a8a72d0dc3c14'), 'white', {renderer: 'canvas'});
#                 var option_3fdb4b09292a415bb99a8a72d0dc3c14 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "China",
#                     "value": 173
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 179
#                 },
#                 {
#                     "name": "France",
#                     "value": 177
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 184
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 110
#                 },
#                 {
#                     "name": "USA",
#                     "value": 166
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "World Map",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 100,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_3fdb4b09292a415bb99a8a72d0dc3c14.setOption(option_3fdb4b09292a415bb99a8a72d0dc3c14);
#         });
#     </script>

# %% [markdown]
# # 词云图

# %%
import pyecharts.options as opts
from pyecharts.charts import WordCloud

data = [
    ("生活资源", "999"),
    ("供热管理", "888"),
    ("供气质量", "777"),
    ("生活用水管理", "688"),
    ("一次供水问题", "588"),
    ("交通运输", "516"),
    ("城市交通", "515"),
    ("环境保护", "683"),
    ("房地产管理", "662"),
    ("城乡建设", "649"),
    ("社会保障与福利", "429"),
    ("社会保障", "707"),
    ("文体与教育管理", "506"),
    ("公共安全", "506"),
    ("公交运输管理", "586"),
    ("出租车运营管理", "585"),
]

(
    WordCloud()
    .add(series_name="热点分析", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="热点分析", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="3e0ffb3bbfce4519803dbf178ca5a40f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_3e0ffb3bbfce4519803dbf178ca5a40f = echarts.init(
#                     document.getElementById('3e0ffb3bbfce4519803dbf178ca5a40f'), 'white', {renderer: 'canvas'});
#                 var option_3e0ffb3bbfce4519803dbf178ca5a40f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u70ed\u70b9\u5206\u6790",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u751f\u6d3b\u8d44\u6e90",
#                     "value": "999",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(103,41,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f9b\u70ed\u7ba1\u7406",
#                     "value": "888",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,152,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f9b\u6c14\u8d28\u91cf",
#                     "value": "777",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,33,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u751f\u6d3b\u7528\u6c34\u7ba1\u7406",
#                     "value": "688",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,113,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u6b21\u4f9b\u6c34\u95ee\u9898",
#                     "value": "588",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,17,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ea4\u901a\u8fd0\u8f93",
#                     "value": "516",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,100,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u57ce\u5e02\u4ea4\u901a",
#                     "value": "515",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(55,55,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883\u4fdd\u62a4",
#                     "value": "683",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,150,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u623f\u5730\u4ea7\u7ba1\u7406",
#                     "value": "662",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(142,9,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u57ce\u4e61\u5efa\u8bbe",
#                     "value": "649",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,72,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u793e\u4f1a\u4fdd\u969c\u4e0e\u798f\u5229",
#                     "value": "429",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,139,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u793e\u4f1a\u4fdd\u969c",
#                     "value": "707",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,38,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6587\u4f53\u4e0e\u6559\u80b2\u7ba1\u7406",
#                     "value": "506",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,12,52)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u5171\u5b89\u5168",
#                     "value": "506",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,91,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u4ea4\u8fd0\u8f93\u7ba1\u7406",
#                     "value": "586",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(21,66,22)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u51fa\u79df\u8f66\u8fd0\u8425\u7ba1\u7406",
#                     "value": "585",
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,58,67)"
#                         }
#                     }
#                 }
#             ],
#             "drawOutOfBound": false,
#             "textStyle": {
#                 "emphasis": {}
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u70ed\u70b9\u5206\u6790",
#             "padding": 5,
#             "itemGap": 10,
#             "textStyle": {
#                 "fontSize": 23
#             }
#         }
#     ]
# };
#                 chart_3e0ffb3bbfce4519803dbf178ca5a40f.setOption(option_3e0ffb3bbfce4519803dbf178ca5a40f);
#         });
#     </script>

# %% [markdown]
# # 仪表盘

# %%
from pyecharts.charts import Gauge

# 仪表盘
gauge = Gauge()
gauge.add('Python小例子', [['Python机器学习', 30]],
          detail_label_opts=opts.GaugeDetailOpts(formatter='{value}%',offset_center=[0,80])
         )
#gauge.render(path="./data/仪表盘.html")
gauge.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a96e1854e6cd4217be55b4252cd2b6b4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a96e1854e6cd4217be55b4252cd2b6b4 = echarts.init(
#                     document.getElementById('a96e1854e6cd4217be55b4252cd2b6b4'), 'white', {renderer: 'canvas'});
#                 var option_a96e1854e6cd4217be55b4252cd2b6b4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "offsetCenter": [
#                     0,
#                     "-40%"
#                 ],
#                 "color": "#333",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "backgroundColor": "transparent",
#                 "borderColor": "transparent",
#                 "borderWidth": 0,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "detail": {
#                 "show": true,
#                 "backgroundColor": "transparent",
#                 "borderWidth": 0,
#                 "borderColor": "transparent",
#                 "offsetCenter": [
#                     0,
#                     80
#                 ],
#                 "formatter": "{value}%",
#                 "color": "auto",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "name": "Python\u5c0f\u4f8b\u5b50",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "Python\u673a\u5668\u5b66\u4e60",
#                     "value": 30
#                 }
#             ],
#             "pointer": {
#                 "show": true,
#                 "length": "80%",
#                 "width": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Python\u5c0f\u4f8b\u5b50"
#             ],
#             "selected": {
#                 "Python\u5c0f\u4f8b\u5b50": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_a96e1854e6cd4217be55b4252cd2b6b4.setOption(option_a96e1854e6cd4217be55b4252cd2b6b4);
#         });
#     </script>

# %% [markdown]
# # 组合图

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar,Line
#from pyecharts.commons.utils import JsCode
from pyecharts.faker import Faker

x_data = ["{}月".format(i) for i in range(1, 13)]
bar = (
        Bar()
        .add_xaxis(x_data)
        .add_yaxis(
            "蒸发量",
            [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3],
            yaxis_index=0,
            color="#d14a61",
        )
        .add_yaxis(
            "降水量",
            [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3],
            yaxis_index=1,
            color="#5793f3",
        )
        .extend_axis(
            yaxis=opts.AxisOpts(
                name="蒸发量",
                type_="value",
                min_=0,
                max_=250,
                position="right",
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(color="#d14a61")
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
            )
        )
        .extend_axis(
            yaxis=opts.AxisOpts(
                type_="value",
                name="温度",
                min_=0,
                max_=25,
                position="left",
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(color="#675bba")
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value} °C"),
                splitline_opts=opts.SplitLineOpts(
                    is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=1)
                ),
            )
        )
        .set_global_opts(
            yaxis_opts=opts.AxisOpts(
                name="降水量",
                min_=0,
                max_=250,
                position="right",
                offset=50,
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(color="#5793f3")
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
            ),
            title_opts=opts.TitleOpts(title="Grid-多 Y 轴示例"),
            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        )
    )

line = (
        Line()
        .add_xaxis(x_data)
        .add_yaxis(
            "平均温度",
            [2.0, 2.2, 3.3, 4.5, 6.3, 10.2, 20.3, 23.4, 23.0, 16.5, 12.0, 6.2],
            yaxis_index=2,
            color="#675bba",
            label_opts=opts.LabelOpts(is_show=False),
        )
    )
bar.overlap(line)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b21d24a6cd5147f88139a7a9d20e411a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b21d24a6cd5147f88139a7a9d20e411a = echarts.init(
#                     document.getElementById('b21d24a6cd5147f88139a7a9d20e411a'), 'white', {renderer: 'canvas'});
#                 var option_b21d24a6cd5147f88139a7a9d20e411a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#5793f3",
#         "#d14a61",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u84b8\u53d1\u91cf",
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u964d\u6c34\u91cf",
#             "yAxisIndex": 1,
#             "legendHoverLink": true,
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u6e29\u5ea6",
#             "connectNulls": false,
#             "yAxisIndex": 2,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "1\u6708",
#                     2.0
#                 ],
#                 [
#                     "2\u6708",
#                     2.2
#                 ],
#                 [
#                     "3\u6708",
#                     3.3
#                 ],
#                 [
#                     "4\u6708",
#                     4.5
#                 ],
#                 [
#                     "5\u6708",
#                     6.3
#                 ],
#                 [
#                     "6\u6708",
#                     10.2
#                 ],
#                 [
#                     "7\u6708",
#                     20.3
#                 ],
#                 [
#                     "8\u6708",
#                     23.4
#                 ],
#                 [
#                     "9\u6708",
#                     23.0
#                 ],
#                 [
#                     "10\u6708",
#                     16.5
#                 ],
#                 [
#                     "11\u6708",
#                     12.0
#                 ],
#                 [
#                     "12\u6708",
#                     6.2
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u84b8\u53d1\u91cf",
#                 "\u964d\u6c34\u91cf",
#                 "\u5e73\u5747\u6e29\u5ea6"
#             ],
#             "selected": {
#                 "\u84b8\u53d1\u91cf": true,
#                 "\u964d\u6c34\u91cf": true,
#                 "\u5e73\u5747\u6e29\u5ea6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1\u6708",
#                 "2\u6708",
#                 "3\u6708",
#                 "4\u6708",
#                 "5\u6708",
#                 "6\u6708",
#                 "7\u6708",
#                 "8\u6708",
#                 "9\u6708",
#                 "10\u6708",
#                 "11\u6708",
#                 "12\u6708"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u964d\u6c34\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#5793f3"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} ml"
#             },
#             "inverse": false,
#             "position": "right",
#             "offset": 50,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 250,
#             "minInterval": 0,
#             "splitLine":

# %% [markdown]
# # K线图

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar,Line,Kline,Grid
from pyecharts.commons.utils import JsCode
import tushare as ts
import pandas as pd
import numpy as np
import talib as ta

# %%
def get_price(code,start,end):
    df=ts.get_k_data(code,start,end)
    df.index=pd.to_datetime(df.date).apply(lambda x:x.strftime('%Y%m%d')).tolist()
    #将成交量单位改为10000手并取整数
    df['volume']=(df['volume']/10000).apply(int)
    return df[['open','close','high','low','volume']]
def get_data(code,start='2021-01-01',end=''):
    df=get_price(code,start,end)
    df['ma5']=df.close.rolling(5).mean()
    df['ma20']=df.close.rolling(20).mean()
    df['macd'],df['macdsignal'],df['macdhist']=ta.MACD(df.close,fastperiod=12,slowperiod=26,signalperiod=9)
    return df.dropna()

# %%
df=get_data('600000')
df.head()
# Out:
#            open  close   high    low  volume     ma5     ma20      macd  \
# 20210225  10.18  10.32  10.37  10.12      89  10.292   9.8820  0.249046
# 20210226  10.24  10.06  10.34  10.06      85  10.206   9.9195  0.227212
# 20210301  10.11  10.10  10.16  10.02      54  10.180   9.9625  0.210707
# 20210302  10.13   9.99  10.22   9.88      74  10.118  10.0020  0.186599
# 20210303   9.97  10.44  10.44   9.95     113  10.182  10.0615  0.201482
#
#           macdsignal  macdhist
# 20210225    0.218524  0.030522
# 20210226    0.220262  0.006950
# 20210301    0.218351 -0.007644
# 20210302    0.212000 -0.025401
# 20210303    0.209897 -0.008415

# %%
def draw_kline(data):
    c = (
        Kline().add_xaxis(data.index.tolist())  #X轴数据
        #y轴数据，默认open、close、high、low，转为list格式
        .add_yaxis(
            series_name="",
            y_axis=data[['open', 'close', 'high', 'low']].values.tolist(),
            itemstyle_opts=opts.ItemStyleOpts(
                color="#ef232a",
                color0="#14b143",
                border_color="#ef232a",
                border_color0="#14b143",
            ),
            #添加标记符
            markpoint_opts=opts.MarkPointOpts(data=[
                opts.MarkPointItem(type_='max', name='最大值'),
                opts.MarkPointItem(type_='min', name='最小值'),
            ]),
            #添加辅助性，如某期间内最大max最小值min均值average
            markline_opts=opts.MarkLineOpts(
                data=[opts.MarkLineItem(type_="average",
                                        value_dim="close")], ),
           
        ).set_global_opts(
            xaxis_opts=opts.AxisOpts(is_scale=True),
            yaxis_opts=opts.AxisOpts(
                is_scale=True,
                #设置网格线之间的阴影面积显示
                splitarea_opts=opts.SplitAreaOpts(
                    is_show=True,
                    areastyle_opts=opts.AreaStyleOpts(opacity=1))),
            #滑动模块选择,添加type_="inside"可隐藏模块
            datazoom_opts=[opts.DataZoomOpts()],
            #设置标题
            title_opts=opts.TitleOpts(title="股票K线图"),
        ))
    return c

# %%
draw_kline(df).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5ac73d5a486c42cd965e658c5baf0b69" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5ac73d5a486c42cd965e658c5baf0b69 = echarts.init(
#                     document.getElementById('5ac73d5a486c42cd965e658c5baf0b69'), 'white', {renderer: 'canvas'});
#                 var option_5ac73d5a486c42cd965e658c5baf0b69 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "data": [
#                 [
#                     10.18,
#                     10.32,
#                     10.37,
#                     10.12
#                 ],
#                 [
#                     10.24,
#                     10.06,
#                     10.34,
#                     10.06
#                 ],
#                 [
#                     10.11,
#                     10.1,
#                     10.16,
#                     10.02
#                 ],
#                 [
#                     10.13,
#                     9.99,
#                     10.22,
#                     9.88
#                 ],
#                 [
#                     9.97,
#                     10.44,
#                     10.44,
#                     9.95
#                 ],
#                 [
#                     10.32,
#                     10.4,
#                     10.44,
#                     10.28
#                 ],
#                 [
#                     10.39,
#                     10.38,
#                     10.46,
#                     10.21
#                 ],
#                 [
#                     10.5,
#                     10.27,
#                     10.54,
#                     10.23
#                 ],
#                 [
#                     10.3,
#                     10.25,
#                     10.42,
#                     10.17
#                 ],
#                 [
#                     10.28,
#                     10.24,
#                     10.31,
#                     10.15
#                 ],
#                 [
#                     10.32,
#                     10.42,
#                     10.49,
#                     10.28
#                 ],
#                 [
#                     10.41,
#                     10.42,
#                     10.55,
#                     10.34
#                 ],
#                 [
#                     10.4,
#                     10.64,
#                     10.76,
#                     10.4
#                 ],
#                 [
#                     10.57,
#                     10.63,
#                     10.76,
#                     10.53
#                 ],
#                 [
#                     10.62,
#                     10.44,
#                     10.64,
#                     10.41
#                 ],
#                 [
#                     10.49,
#                     10.55,
#                     10.57,
#                     10.42
#                 ],
#                 [
#                     10.53,
#                     10.17,
#                     10.57,
#                     10.08
#                 ],
#                 [
#                     10.14,
#                     10.27,
#                     10.4,
#                     10.14
#                 ],
#                 [
#                     10.28,
#                     10.3,
#                     10.35,
#                     10.2
#                 ],
#                 [
#                     10.29,
#                     10.2,
#                     10.33,
#                     10.15
#                 ],
#                 [
#                     10.24,
#                     10.15,
#                     10.3,
#                     10.13
#                 ],
#                 [
#                     10.2,
#                     10.14,
#                     10.25,
#                     10.13
#                 ],
#                 [
#                     10.12,
#                     10.0,
#                     10.12,
#                     9.92
#                 ],
#                 [
#                     10.17,
#                     10.53,
#                     10.53,
#                     10.14
#                 ],
#                 [
#                     10.53,
#                     10.51,
#                     10.56,
#                     10.39
#                 ],
#                 [
#                     10.51,
#                     10.41,
#                     10.53,
#                     10.33
#                 ],
#                 [
#                     10.46,
#                     10.28,
#                     10.47,
#                     10.19
#                 ],
#                 [
#                     10.28,
#                     10.22,
#                     10.31,
#                     10.2
#                 ],
#                 [
#                     10.26,
#                     10.17,
#                     10.27,
#                     10.1
#                 ],
#                 [
#                     10.15,
#                     10.18,
#                     10.22,
#                     10.08
#                 ],
#                 [
#                     10.16,
#                     10.11,
#                     10.16,
#                     10.05
#                 ],
#                 [
#                     10.1,
#                     10.25,
#                     10.27,
#                     10.04
#                 ],
#                 [
#                     10.26,
#                     10.28,
#                     10.34,
#                     10.19
#                 ],
#                 [
#                     10.34,
#                     10.11,
#                     10.34,
#                     10.09
#                 ],
#                 [
#                     10.1,
#                     9.95,
#                     10.13,
#                     9.9
#                 ],
#                 [
#                     9.97,
#                     10.06,
#                     10.07,
#                     9.94
#                 ],
#                 [
#                     10.07,
#                     10.1,
#                     10.16,
#                     9.97
#                 ],
#                 [
#                     10.07,
#                     10.02,
#                     10.1,
#                     10.0
#                 ],
#                 [
#                     9.99,
#                     10.1,
#                     10.14,
#                     9.98
#                 ],
#                 [
#                     10.12,
#                     9.95,
#                     10.12,
#                     9.92
#                 ],
#                 [
#                     9.94,
#                     9.95,
#                     9.99,
#                     9.9
#                 ],
#                 [
#                     9.97,
#                     9.82,
#                     10.02,
#                     9.8
#                 ],
#                 [
#                     9.85,
#                     9.79,
#                     9.86,
#                     9.76
#                 ],
#                 [
#                     9.85,
#                     9.77,
#                     9.85,
#                     9.7
#                 ],
#                 [
#                     9.8,
#                     10.06,
#                     10.07,
#                     9.78
#                 ],
#                 [
#                     9.8,
#                     9.57,
#                     9.8,
#                     9.48
#                 ],
#                 [
#                     9.49,
#                     9.62,

# %%
def split_data_part(data) -> Sequence:
    mark_line_data = []
    idx = 0
    tag = 0
    vols = 0
    for i in range(len(data)):
        #开盘价小于收盘价
        if data['open'][i]<data['close'][i] and tag == 0:
            idx = i
            vols = data["volume"][i]
            tag = 1
        if tag == 1:
            vols += data["volume"][i]
        if data['open'][i]<data['close'][i] or tag == 1:
            mark_line_data.append(
                [
                    {
                        "xAxis": idx,
                        "yAxis": float("%.2f" % data["high"][idx])
                        if data["close"][idx] > data["open"][idx]
                        else float("%.2f" % data["low"][idx]),
                        "value": vols,
                    },
                    {
                        "xAxis": i,
                        "yAxis": float("%.2f" % data["high"][i])
                        if data["close"][i] > data["open"][i]
                        else float("%.2f" % data["low"][i]),
                    },
                ]
            )
            idx = i
            vols = data["volume"][i]
            tag = 2
        if tag == 2:
            vols += data["volume"][i]
            
        if data['open'][i]<data['close'][i] and tag == 2:
            mark_line_data.append(
                [
                    {
                        "xAxis": idx,
                        "yAxis": float("%.2f" % data["high"][idx])
                        if data["close"][i] > data["open"][i]
                        else float("%.2f" % data["low"][i]),
                        "value": str(float("%.2f" % (vols / (i - idx + 1)))) + " M",
                    },
                    {
                        "xAxis": i,
                        "yAxis": float("%.2f" % data["high"][i])
                        if data["close"][i] > data["open"][i]
                        else float("%.2f" % data["low"][i]),
                    },
                ]
            )
            idx = i
            vols = data["volume"][i]
    return mark_line_data

# %% [markdown]
# [pyecharts 之 JsCode 的妙用](https://zhuanlan.zhihu.com/p/133533187)
# 是一段字符串包含着 Javascript 的代码, 在渲染到 html 的时候变成 html 可识别的 js 匿名函数

# %%
def plot_kline_volume_signal(data):
    kline = (
        Kline()
        .add_xaxis(xaxis_data=list(data.index))
        .add_yaxis(
            series_name="klines",
            y_axis=data[["open", "close", "low", "high"]].values.tolist(),
            #设置K线两种颜色，上涨红色，下跌绿色
            itemstyle_opts=opts.ItemStyleOpts(
                color="#ef232a",
                color0="#14b143",
                border_color="#ef232a",
                border_color0="#14b143",),
            #添加标记符
            markpoint_opts=opts.MarkPointOpts(data=[
                opts.MarkPointItem(type_='max', name='最大值'),
                opts.MarkPointItem(type_='min', name='最小值'),
            ]),
            #添加辅助性，如某期间内最大max最小值min均值average
            markline_opts=opts.MarkLineOpts(
                #data=[opts.MarkLineItem(type_="average",
                #                        value_dim="close")], 
                label_opts=opts.LabelOpts(
                    position="middle", color="blue", font_size=15
                ),
                #data=split_data_part(data),
                symbol=["circle", "none"],),)
        .set_global_opts(
            legend_opts=opts.LegendOpts(
                is_show=True, pos_top=1, pos_left='center'),  
            #有三个图
            datazoom_opts=[
                opts.DataZoomOpts(is_show=False,type_="inside",xaxis_index=[0, 0],range_end=100,),
                opts.DataZoomOpts(is_show=False, xaxis_index=[0, 1], range_end=100),
                opts.DataZoomOpts(is_show=True, xaxis_index=[0, 2], pos_top="95%",range_end=100,),
            ],
            title_opts=opts.TitleOpts(title="股票K线图", pos_left="0"),
            yaxis_opts=opts.AxisOpts(
                is_scale=True,
                splitarea_opts=opts.SplitAreaOpts(
                    is_show=True,
                    areastyle_opts=opts.AreaStyleOpts(opacity=1)),
            ),
        ))

    bar = (Bar().add_xaxis(xaxis_data=list(data.index)).add_yaxis(
        series_name="volume",
        y_axis=data["volume"].tolist(),
        xaxis_index=1,
        yaxis_index=1,
        label_opts=opts.LabelOpts(is_show=False),
        itemstyle_opts=opts.ItemStyleOpts(color=JsCode("""
                function(params) {
                    var colorList;
                    if (barData[params.dataIndex][1] > barData[params.dataIndex][0]) {
                        colorList = '#ef232a';
                    } else {
                        colorList = '#14b143';
                    }
                    return colorList;
                }
                """)),
    ).set_global_opts(
        xaxis_opts=opts.AxisOpts(
            type_="category",
            grid_index=1,
            axislabel_opts=opts.LabelOpts(is_show=False),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    ))

    line = (Line()
        .add_xaxis(xaxis_data=list(data.index))
        .add_yaxis(
          series_name="ma5",
          y_axis=data["ma5"].tolist(),
          xaxis_index=1,
          yaxis_index=1,
          label_opts=opts.LabelOpts(is_show=False),
          is_symbol_show=False,) #画折线不显示小圆圈
        .add_yaxis(
          series_name="ma20",
          y_axis=data["ma20"].tolist(),
          xaxis_index=1,
          yaxis_index=1,
          label_opts=opts.LabelOpts(is_show=False),
          is_symbol_show=False,))

    # Bar-2 (Overlap Bar + Line)
    bar_2 = (Bar().add_xaxis(xaxis_data=data.index.tolist()).add_yaxis(
        series_name="MACD",
        y_axis=data["macdhist"].values.tolist(),
        xaxis_index=2,
        yaxis_index=2,
        label_opts=opts.LabelOpts(is_show=False),
        itemstyle_opts=opts.ItemStyleOpts(color=JsCode("""
                        function(params) {
                            var colorList;
                            if (params.data >= 0) {
                              colorList = '#ef232a';
                            } else {
                              colorList = '#14b143';
                            }
                            return colorList;
                        }
                        """)),
    ).set_global_opts(
        xaxis_opts=opts.AxisOpts(
            type_="category",
            grid_index=2,
            axislabel_opts=opts.LabelOpts(is_show=False),
        ),
        yaxis_opts=opts.AxisOpts(
            grid_index=2,
            split_number=4,
            axisline_opts=opts.AxisLineOpts(is_on_zero=False),
            axistick_opts=opts.AxisTickOpts(is_show=False),
            splitline_opts=opts.SplitLineOpts(is_show=False),
            axislabel_opts=opts.LabelOpts(is_show=True),
        ),
        legend_opts=opts.LegendOpts(is_show=True, pos_top=1,pos_right=20),
    ))
    line_2 = (
        Line()
        .add_xaxis(xaxis_data=data.index.tolist())
        .add_yaxis(
          series_name="DIFF",
          y_axis=data["macd"],
          xaxis_index=2,
          yaxis_index=2,
          label_opts=opts.LabelOpts(is_show=False),
          is_symbol_show=False,
          itemstyle_opts=opts.ItemStyleOpts(color="#ec0000"),)
        .add_yaxis(
          series_name="DEA",
          y_axis=data["macdsignal"],
          xaxis_index=2,
          yaxis_index=2,
          label_opts=opts.LabelOpts(is_show=False),
          is_symbol_show=False,
          itemstyle_opts=opts.ItemStyleOpts(color="#00da3c"),)
        .set_global_opts(legend_opts=opts.LegendOpts(is_show=False)))
    # 最下面的柱状图和折线图
    overlap_bar_line = bar_2.overlap(line_2)
    grid_chart = Grid(init_opts=opts.InitOpts(
        width="900px",height="600px",
        animation_opts=opts.AnimationOpts(animation=False),))
    grid_chart.add_js_funcs("var barData={}".format(data[["open", "close"]].values.tolist()))
    overlap_kline_line = kline.overlap(line)
    grid_chart.add(overlap_kline_line,
        #kline,
        grid_opts=opts.GridOpts(pos_left="3%", pos_right="3%", height="45%"),)
    grid_chart.add(bar,
        grid_opts=opts.GridOpts(pos_left="3%",pos_right="3%",pos_top="60%",height="15%"),)
    grid_chart.add(overlap_bar_line,
        grid_opts=opts.GridOpts(pos_left="3%",pos_right="3%",pos_top="80%",height="15%"),)
    return grid_chart

# %%
plot_kline_volume_signal(df).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fb42b030c25341299862138d4b7cd011" style="width:900px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fb42b030c25341299862138d4b7cd011 = echarts.init(
#                     document.getElementById('fb42b030c25341299862138d4b7cd011'), 'white', {renderer: 'canvas'});
#                     var barData=[[9.16, 9.21], [9.2, 9.2], [9.14, 9.34], [9.35, 9.33], [9.35, 9.35], [9.35, 9.21], [9.22, 9.3], [9.27, 9.36], [9.35, 9.39], [9.5, 9.44], [9.44, 9.6], [9.59, 9.68], [9.65, 9.5], [9.51, 9.49], [9.48, 9.31], [9.29, 9.24], [9.21, 9.2], [9.19, 9.25], [9.25, 9.18], [9.21, 9.48], [9.46, 9.96], [9.87, 9.74], [9.71, 9.78], [9.73, 9.8], [9.8, 10.24], [10.23, 10.24], [10.22, 10.2], [10.19, 10.21], [10.32, 10.35], [10.35, 10.49], [10.44, 10.23], [10.23, 10.3], [10.33, 10.12], [10.18, 10.32], [10.24, 10.06], [10.11, 10.1], [10.13, 9.99], [9.97, 10.44], [10.32, 10.4], [10.39, 10.38], [10.5, 10.27], [10.3, 10.25], [10.28, 10.24], [10.32, 10.42], [10.41, 10.42], [10.4, 10.64], [10.57, 10.63], [10.62, 10.44], [10.49, 10.55], [10.53, 10.17], [10.14, 10.27], [10.28, 10.3], [10.29, 10.2], [10.24, 10.15], [10.2, 10.14], [10.12, 10.0], [10.17, 10.53], [10.53, 10.51], [10.51, 10.41], [10.46, 10.28], [10.28, 10.22], [10.26, 10.17], [10.15, 10.18], [10.16, 10.11], [10.1, 10.25], [10.26, 10.28], [10.34, 10.11], [10.1, 9.95], [9.97, 10.06], [10.07, 10.1], [10.07, 10.02], [9.99, 10.1], [10.12, 9.95], [9.94, 9.95], [9.97, 9.82], [9.85, 9.79], [9.85, 9.77], [9.8, 10.06], [9.8, 9.57], [9.49, 9.62], [9.62, 9.55], [9.58, 9.47], [9.44, 9.57], [9.56, 9.64], [9.61, 9.61], [9.62, 9.71], [9.72, 9.73], [9.7, 9.74], [9.71, 9.64], [9.62, 9.68], [9.72, 9.61], [9.6, 9.61], [9.62, 9.84], [9.83, 9.87], [9.84, 9.81], [9.85, 9.87], [9.86, 9.79], [9.75, 9.71], [9.73, 9.74], [9.73, 9.75], [9.77, 9.75], [9.78, 9.75], [9.76, 9.83], [9.81, 9.73], [9.73, 9.75], [9.76, 9.69], [9.67, 9.55], [9.56, 9.57], [9.57, 9.56], [9.56, 9.62], [9.58, 9.56], [9.58, 9.52], [9.53, 9.51], [9.52, 9.54], [9.54, 9.6], [9.58, 9.53], [9.53, 9.5], [9.52, 9.52], [9.53, 9.55], [9.53, 9.45], [9.47, 9.44], [9.43, 9.51], [9.53, 9.55], [9.57, 9.46], [9.45, 9.43], [9.48, 9.43], [9.46, 9.48], [9.49, 9.35], [9.35, 9.46], [9.53, 9.5], [9.5, 9.53], [9.53, 9.51], [9.51, 9.55], [9.58, 9.64], [9.6, 9.58], [9.57, 9.34], [9.36, 9.15], [9.16, 9.21], [9.25, 9.12], [9.13, 9.03], [9.03, 9.13], [9.13, 9.12], [9.12, 9.07], [9.06, 9.05], [9.05, 9.08], [9.06, 9.17], [9.18, 9.2], [9.18, 9.21], [9.21, 9.17], [9.16, 9.18], [9.19, 9.22], [9.23, 9.19], [9.2, 9.33], [9.34, 9.23], [9.25, 9.27], [9.3, 9.2], [9.22, 9.21], [9.23, 9.19], [9.18, 9.14], [9.16, 9.17], [9.05, 8.96], [8.98, 9.05], [9.03, 9.18], [9.2, 9.23], [9.24, 9.24], [9.22, 9.21], [9.21, 9.34], [9.34, 9.34], [9.32, 9.3], [9.32, 9.41], [9.38, 9.39], [9.39, 9.21], [9.21, 9.19], [9.2, 9.12], [9.11, 9.11], [9.0, 9.03], [9.1, 9.03], [9.04, 9.02], [9.02, 9.02], [8.98, 9.03], [9.01, 9.02], [9.03, 9.0], [9.05, 9.08], [9.12, 9.15], [9.12, 9.14], [9.14, 9.07], [9.07, 9.04], [9.05, 9.07], [9.06, 9.02], [9.03, 9.01], [9.03, 9.02], [9.05, 9.04], [9.07, 9.07], [9.03, 9.03], [9.06, 9.03], [9.01, 8.99], [8.99, 8.96], [8.96, 8.94], [8.69, 8.72], [8.71, 8.54], [8.59, 8.53], [8.53, 8.51], [8.51, 8.53], [8.48, 8.49], [8.5, 8.54], [8.53, 8.48], [8.48, 8.62], [8.64, 8.65], [8.66, 8.75], [8.7, 8.73], [8.67, 8.65], [8.61, 8.56], [8.56, 8.65], [8.63, 8.6], [8.61, 8.63], [8.61, 8.68], [8.68, 8.64], [8.61, 8.56], [8.57, 8.59], [8.54, 8.51], [8.53, 8.56], [8.56, 8.58], [8.58, 8.59], [8.59, 8.6], [8.69, 8.68], [8.7, 8.67], [8.69, 8.75], [8.73, 8.77], [8.79, 8.65], [8.64, 8.57], [8.54, 8.55], [8.56, 8.6], [8.61, 8.56], [8.55, 8.58], [8.55, 8.61], [8.62, 8.57], [8.58, 8.58], [8.58, 8.54], [8.54, 8.56], [8.56, 8.57], [8.57, 8.54], [8.54, 8.54], [8.54, 8.53], [8.54, 8.57], [8.57, 8.64], [8.66, 8.57], [8.57, 8.71], [8.72, 8.72], [8.74, 8.73], [8.75, 8.69], [8.73, 8.72], [8.72, 8.59], [8.57, 8.57], [8.58, 8.63], [8.63, 8.64], [8.66, 8.8], [8.78, 8.76], [8.79, 8.69], [8.68, 8.56], [8.57, 8.57], [8.55, 8.45], [8.48, 8.41], [8.48, 8.52], [8.53, 8.65], [8.64, 8.64], [8.66, 8.69], [8.7, 8.74], [8.69, 8.6], [8.59, 8.55], [8.58, 8.59], [8.6, 8.56], [8.55, 8.67], [8.64, 8.6], [8.57, 8.58], [8.59, 8.54], [8.54, 8.44], [8.44, 8.43], [8.44, 8.39], [8.39, 8.44], [8.41, 8.42], [8.44, 8. ...
#                 var option_fb42b030c25341299862138d4b7cd011 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "klines",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 [
#                     9.16,
#                     9.21,
#                     9.07,
#                     9.25
#                 ],
#                 [
#                     9.2,
#                     9.2,
#                     9.04,
#                     9.2
#                 ],
#                 [
#                     9.14,
#                     9.34,
#                     9.14,
#                     9.35
#                 ],
#                 [
#                     9.35,
#                     9.33,
#                     9.18,
#                     9.45
#                 ],
#                 [
#                     9.35,
#                     9.35,
#                     9.25,
#                     9.42
#                 ],
#                 [
#                     9.35,
#                     9.21,
#                     9.2,
#                     9.46
#                 ],
#                 [
#                     9.22,
#                     9.3,
#                     9.1,
#                     9.31
#                 ],
#                 [
#                     9.27,
#                     9.36,
#                     9.24,
#                     9.4
#                 ],
#                 [
#                     9.35,
#                     9.39,
#                     9.28,
#                     9.48
#                 ],
#                 [
#                     9.5,
#                     9.44,
#                     9.44,
#                     9.75
#                 ],
#                 [
#                     9.44,
#                     9.6,
#                     9.39,
#                     9.64
#                 ],
#                 [
#                     9.59,
#                     9.68,
#                     9.5,
#                     9.74
#                 ],
#                 [
#                     9.65,
#                     9.5,
#                     9.48,
#                     9.7
#                 ],
#                 [
#                     9.51,
#                     9.49,
#                     9.45,
#                     9.59
#                 ],
#                 [
#                     9.48,
#                     9.31,
#                     9.28,
#                     9.49
#                 ],
#                 [
#                     9.29,
#                     9.24,
#                     9.19,
#                     9.3
#                 ],
#                 [
#                     9.21,
#                     9.2,
#                     9.18,
#                     9.3
#                 ],
#                 [
#                     9.19,
#                     9.25,
#                     9.18,
#                     9.4
#                 ],
#                 [
